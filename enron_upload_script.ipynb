# %%
import numpy as np
import pandas as pd
import requests

from subprocess import check_output

# %%
# Read the data into a DataFrame
emails_df = pd.read_csv('./enron_05_17_2015_filtered.csv', delimiter="#")
print(emails_df.shape)
# Out:
# (374949, 16)

# %%
emails_df.head()
# Out:
#    index                                     Message-ID  \
# 0      0  <15464986.1075855378456.JavaMail.evans@thyme>
# 1      1  <30795301.1075855687494.JavaMail.evans@thyme>
# 2      2  <25459584.1075855687536.JavaMail.evans@thyme>
# 3      3  <13116875.1075855687561.JavaMail.evans@thyme>
# 4      4   <2707340.1075855687584.JavaMail.evans@thyme>
#
#                       file                       Date  \
# 0   allen-p/_sent_mail/10.  2001-05-04 13:51:00-07:00
# 1  allen-p/_sent_mail/102.  2000-10-16 06:44:00-07:00
# 2  allen-p/_sent_mail/104.  2000-10-13 06:45:00-07:00
# 3  allen-p/_sent_mail/105.  2000-10-09 07:16:00-07:00
# 4  allen-p/_sent_mail/106.  2000-10-09 07:00:00-07:00
#
#                                      From  \
# 0  frozenset({'phillip.allen@enron.com'})
# 1  frozenset({'phillip.allen@enron.com'})
# 2  frozenset({'phillip.allen@enron.com'})
# 3  frozenset({'phillip.allen@enron.com'})
# 4  frozenset({'phillip.allen@enron.com'})
#
# ...

# %%
filtered = emails_df[emails_df['index'] >=
          83000]
filtered.shape
# Out:
# (291949, 16)

# %%
filename = "enron_05_17_2015_filtered.csv"
filtered.to_csv(filename, index=False, sep='#', encoding='utf-8')
